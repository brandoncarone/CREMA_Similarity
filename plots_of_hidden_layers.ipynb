# %%
import numpy as np

# %%
from numpy import genfromtxt
my_data = genfromtxt('model_hidden_layer_pred.csv', delimiter=',')

# %%
my_data.shape
# Out:
# (283, 294)

# %%
import matplotlib.pyplot as plt


plt.imshow(my_data, cmap='coolwarm', interpolation='nearest')
plt.show()
